# %%
import tkinter as tk
from tkinter import *
import numpy as np
import copy
import random

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input, Flatten
from tensorflow.keras.losses import MSE
from tensorflow.keras.optimizers import Adam

from collections import deque, namedtuple
from gym import Env
from gym.spaces import Discrete, MultiDiscrete

import time
import random
# Out:
# C:\Users\parij\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # 1. Rubik's Cube GUI using Tkinter

# %%
COLOR_KEY = {
    0 : 'orange',
    1 : 'green',
    2 : 'white',
    3 : 'blue',
    4 : 'yellow',
    5 : 'red'
}


class RubiksCubeGUI:
    def __init__(self, isDesign=True, cube=None):
        self.root = Tk()
        self.cube_colors = np.array([[[0] * 3 for _ in range(3)], 
                                     [[1] * 3 for _ in range(3)],
                                     [[2] * 3 for _ in range(3)],
                                     [[3] * 3 for _ in range(3)],
                                     [[4] * 3 for _ in range(3)],
                                     [[5] * 3 for _ in range(3)]])
        
        self.isDesign = isDesign
        if cube is not None:
            self.cube = cube.reshape((6, 3, 3))
        else:
            self.cube = np.copy(self.cube_colors)
            
        self.actions = { 
            0: self.top,
            1: lambda: self.top(clockwise=False),
            2: self.bottom,
            3: lambda: self.bottom(clockwise=False),
            4: self.left,
            5: lambda: self.left(clockwise=False),
            6: self.right,
            7: lambda: self.right(clockwise=False),
            8: self.front,
            9: lambda: self.front(clockwise=False),
            10: self.back,
            11: lambda: self.back(clockwise=False),
        }
        
        self.cur_colour = 2
        self.cube_grid = []
    
    def set_colour(self, c):
        self.cur_colour = c

    def change_color(self, face, row, col):
        self.cube[face][row][col] = self.cur_colour
        self.cube_grid[face][row][col].config(bg=COLOR_KEY[self.cube[face][row][col]])
        
    def shuffleBoard(self):
        self.shuffle()
        for face in range(6):
            for row in range(3):
                for col in range(3):
                    self.cube_grid[face][row][col].config(bg=COLOR_KEY[self.cube[face][row][col]])
        
    def saveBoard(self):
        noc = [0, 0, 0, 0, 0, 0]
        for face in range(6):
            for row in range(3):
                for col in range(3):
                    noc[self.cube[face][row][col]] += 1
                    
        if noc == [9, 9, 9, 9, 9, 9]:
            self.root.destroy()
        
    def designCube(self):
        frame = Frame(self.root)
        frame.pack()
        bottomframe = Frame(frame)
        bottomframe.pack(side=BOTTOM)

        redbutton = Button(frame, text='Red', fg='red', bg='black', command=lambda: self.set_colour(5))
        redbutton.pack(side=LEFT)

        greenbutton = Button(frame, text='Green', fg='green', bg='black', command=lambda: self.set_colour(1))
        greenbutton.pack(side=LEFT)

        bluebutton = Button(frame, text='Blue', fg='blue', bg='black', command=lambda: self.set_colour(3))
        bluebutton.pack(side=LEFT)

        yellowbutton = Button(frame, text='Yellow', fg='yellow', bg='black', command=lambda: self.set_colour(4))
        yellowbutton.pack(side=LEFT)

        whitebutton = Button(frame, text='White', fg='white', bg='black', command=lambda: self.set_colour(2))
        whitebutton.pack(side=LEFT)

        orangebutton = Button(frame, text='Orange', fg='orange', bg='black', command=lambda: self.set_colour(0))
        orangebutton.pack(side=LEFT)
        
        shufflebutton = Button(bottomframe, text='SHUFFLE', fg='black', bg='white', command=lambda: self.shuffleBoard())
        shufflebutton.pack(side=LEFT)
        
        savebutton = Button(bottomframe, text='SAVE', fg='black', bg='white', command=lambda: self.saveBoard())
        savebutton.pack(side=LEFT)
        
        # Create a frame for the grid squares
        grid_frames = []
        main_frame = tk.Frame(self.root)
        main_frame.pack(padx=10, pady=10)

        for i in range(6):
            grid_frame = tk.Frame(main_frame)
            if i == 0:
                grid_frame.grid(row=0, column=1, padx=5, pady=5)
            elif i == 5:
                grid_frame.grid(row=2, column=1, padx=5, pady=5)
            else:
                grid_frame.grid(row=1, column=i-1, padx=5, pady=5)

            grid_frames.append(grid_frame)
            # Creating the grids
            squares = []

            for row in range(3):
                square_row = []
                for col in range(3):
                    square = tk.Frame(grid_frames[i], width=50, height=50)
                    square.grid(row=row, column=col, padx=1, pady=1)
                    # Associate a button with each square
                    button = tk.Button(square, height=3, width=5, bg=COLOR_KEY[self.cube[i][row][col]])
                    button.pack()
                    if self.isDesign and (row != 1 or col != 1):
                        button.config(command=lambda r=row, c=col, face=i: self.change_color(face, r, c))
                    square_row.append(button)

                squares.append(square_row)
            self.cube_grid.append(squares)

        self.root.mainloop()
        
    def rotate_face_clockwise(self, face):
        self.cube[face] = np.rot90(self.cube[face], 3)

    def rotate_face_counterclockwise(self, face):
        self.cube[face] = np.rot90(self.cube[face])

    def top(self, clockwise=True):
        if clockwise:
            self.rotate_face_clockwise(0)
            temp = np.copy(self.cube[1, 0, :])
            self.cube[1, 0, :] = self.cube[2, 0, :]
            self.cube[2, 0, :] = self.cube[3, 0, :]
            self.cube[3, 0, :] = self.cube[4, 0, :]
            self.cube[4, 0, :] = temp  
        else:
            self.rotate_face_counterclockwise(0)
            temp = np.copy(self.cube[1, 0, :])
            self.cube[1, 0, :] = self.cube[4, 0, :]
            self.cube[4, 0, :] = self.cube[3, 0, :]
            self.cube[3, 0, :] = self.cube[2, 0, :]
            self.cube[2, 0, :] = temp
        return self.cube

    def bottom(self, clockwise=True):
        if clockwise:
            self.rotate_face_counterclockwise(5)
            temp = np.copy(self.cube[1, 2, :])
            self.cube[1, 2, :] = self.cube[2, 2, :]
            self.cube[2, 2, :] = self.cube[3, 2, :]
            self.cube[3, 2, :] = self.cube[4, 2, :]
            self.cube[4, 2, :] = temp
        else:
            self.rotate_face_clockwise(5)
            temp = np.copy(self.cube[1, 2, :])
            self.cube[1, 2, :] = self.cube[4, 2, :]
            self.cube[4, 2, :] = self.cube[3, 2, :]
            self.cube[3, 2, :] = self.cube[2, 2, :]
            self.cube[2, 2, :] = temp
        return self.cube

    def left(self, clockwise=True):
        if clockwise:
            self.rotate_face_clockwise(1)
            temp = np.copy(self.cube[0, :, 0])
            self.cube[0, :, 0] = self.cube[4, ::-1, 2]
            self.cube[4, :, 2] = self.cube[5, ::-1, 0]
            self.cube[5, :, 0] = self.cube[2, :, 0]
            self.cube[2, :, 0] = temp
        else:
            self.rotate_face_counterclockwise(1)
            temp = np.copy(self.cube[0, :, 0])
            self.cube[0, :, 0] = self.cube[2, :, 0]
            self.cube[2, :, 0] = self.cube[5, :, 0]
            self.cube[5, :, 0] = self.cube[4, ::-1, 2]
            self.cube[4, :, 2] = temp[::-1]
        return self.cube

    def right(self, clockwise=True):
        if clockwise:
            self.rotate_face_clockwise(3)
            temp = np.copy(self.cube[0, :, 2])
            self.cube[0, :, 2] = self.cube[2, :, 2]
            self.cube[2, :, 2] = self.cube[5, :, 2]
            self.cube[5, :, 2] = self.cube[4, ::-1, 0]
            self.cube[4, :, 0] = temp[::-1]
        else:
            self.rotate_face_counterclockwise(3)
            temp = np.copy(self.cube[0, :, 2])
            self.cube[0, :, 2] = self.cube[4, ::-1, 0]
            self.cube[4, :, 0] = self.cube[5, ::-1, 2]
            self.cube[5, ::-1, 2] = self.cube[2, :, 2]
            self.cube[2, :, 2] = temp
        return self.cube

    def front(self, clockwise=True):
        if clockwise:
            self.rotate_face_clockwise(2)
            temp = np.copy(self.cube[0, 2, :])
            self.cube[0, 2, :] = self.cube[1, ::-1, 2]
            self.cube[1, :, 2] = self.cube[5, 0, :]
            self.cube[5, 0, :] = self.cube[3, ::-1, 0]
            self.cube[3, :, 0] = temp
        else:
            self.rotate_face_counterclockwise(2)
            temp = np.copy(self.cube[0, 2, :])
            self.cube[0, 2, :] = self.cube[3, :, 0]
            self.cube[3, :, 0] = self.cube[5, 0, ::-1]
            self.cube[5, 0, :] = self.cube[1, :, 2]
            self.cube[1, :, 2] = temp[::-1]
        return self.cube

    def back(self, clockwise=True):
        if clockwise:
            self.rotate_face_clockwise(4)
            temp = np.copy(self.cube[0, 0, :])
            self.cube[0, 0, :] = self.cube[3, :, 2]
            self.cube[3, :, 2] = self.cube[5, 2, ::-1]
            self.cube[5, 2, :] = self.cube[1, :, 0]
            self.cube[1, :, 0] = temp[::-1]
        else:
            self.rotate_face_counterclockwise(4)
            temp = np.copy(self.cube[0, 0, :])
            self.cube[0, 0, :] = self.cube[1, ::-1, 0]
            self.cube[1, :, 0] = self.cube[5, 2, :]
            self.cube[5, 2, :] = self.cube[3, ::-1, 2]
            self.cube[3, :, 2] = temp
        return self.cube    
    
    def shuffle(self):
        n = random.randint(5, 15)
        for i in range(n):
            r = random.randint(0, 5)
            self.actions[2 * r]()
        
        return self.cube

# %% [markdown]
# # 2. Reinforcement Learning Environment

# %%
# Values of the constants
cube_number = 100

# %%
class CubeEnv (Env):
    def __init__(self):
        # Moves that we can make
        self.action_space = Discrete(12)
        # All possible combinations of a rubiks cube
        self.observation_space = MultiDiscrete([6]*54)
        
        #instantiating RubiksCubeGUI class
        self.myCube = RubiksCubeGUI()
        self.myCube.designCube()
        # Use the cube state obtained from the RubiksCubeGUI class
        self.state = self.myCube.cube.reshape(54,)
        # Maximum no. of moves the agent is allowed to make
        self.moves_length = cube_number
        self.root = Tk()
        self.cube_grid = []
        
        grid_frames = []
        main_frame = tk.Frame(self.root)
        main_frame.pack(padx=10, pady=10)

        for i in range(6):
            grid_frame = tk.Frame(main_frame)
            if i == 0:
                grid_frame.grid(row=0, column=1, padx=5, pady=5)
            elif i == 5:
                grid_frame.grid(row=2, column=1, padx=5, pady=5)
            else:
                grid_frame.grid(row=1, column=i-1, padx=5, pady=5)

            grid_frames.append(grid_frame)
            # Creating the grids
            squares = []

            for row in range(3):
                square_row = []
                for col in range(3):
                    square = tk.Frame(grid_frames[i], width=50, height=50, bg=COLOR_KEY[self.myCube.cube[i][row][col]])
                    square.grid(row=row, column=col, padx=1, pady=1)
                    square_row.append(square)
                squares.append(square_row)
            self.cube_grid.append(squares)

        
    
    def step(self, action):
        # Applying the action
        self.state = self.myCube.actions[action]().reshape(54,)
        self.myCube.cube = self.state.reshape(6, 3, 3)
        # Reduce no. of moves left by 1
        self.moves_length -= 1
        
        # Calculating the reward
        if (self.state.reshape(6, 3, 3) == self.myCube.cube_colors).all():
            reward = 100
            done = True
        else:
            reward = 0
            done = False
            
#         # Check if no. of moves exceeded maximum number of moves
#         if  (self.state == self.myCube.cube_colors).all():
#             done = True
#         else:
#             done = False
        if self.moves_length <= 0: done = True
        
        info = {}
        
        return self.state, reward, done, info
    
    def render(self):
        state3d = self.state.reshape(6, 3, 3)
        for face in range(6):
            for row in range(3):
                for col in range(3):
                    self.cube_grid[face][row][col].configure(bg=COLOR_KEY[state3d[face][row][col]])
        
    def reset(self):
        self.myCube.cube = np.copy(self.myCube.cube_colors)
        self.state = self.myCube.shuffle().reshape(54,)
        self.moves_length = cube_number
        return self.state

# %%
env = CubeEnv()
env.reset()
env.state.shape
# Out:
# (54,)

# %%
for episode in range(10):
    state = env.reset()
    done = False
    score = 0
    i = 0
    
    while not done and i < 30:
        i += 1
        action = env.action_space.sample()
        n_state, reward, done, _ = env.step(action)
        score += reward
    print(f'Episode: {episode + 1} Score: {score}')
    
env.root.mainloop()
# Out:
# Episode: 1 Score: 0
# Episode: 2 Score: 0
# Episode: 3 Score: 0
# Episode: 4 Score: 0
# Episode: 5 Score: 0
# Episode: 6 Score: 0
# Episode: 7 Score: 0
# Episode: 8 Score: 0
# Episode: 9 Score: 0
# Episode: 10 Score: 0

# %% [markdown]
# # 3.0 PPO

# %%
from stable_baselines3 import PPO

model = PPO('MlpPolicy', env, verbose=1)

model.learn(total_timesteps=1000000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.14     |
# |    ep_rew_mean     | 96       |
# | time/              |          |
# |    fps             | 388      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.9         |
# |    ep_rew_mean          | 92           |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0029897685 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.8         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.00688     |
# |    value_loss           | 135          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.1          |
# |    ep_rew_mean          | 98           |
# | time/                   |              |
# |    fps                  | 266          |
# |    iterations           | 3            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0024515828 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.67        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.6         |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | -0.00424     |
# |    value_loss           | 112          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.3         |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 4           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008677967 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.6        |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | -0.00609    |
# |    value_loss           | 82.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.16         |
# |    ep_rew_mean          | 95           |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 5            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0019297693 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.905        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 161          |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.00556     |
# |    value_loss           | 120          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.96         |
# |    ep_rew_mean          | 95           |
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 6            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0020169849 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.589       |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.3         |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 103          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.4          |
# |    ep_rew_mean          | 95           |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 7            |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0050824196 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.1         |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 66.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.54        |
# |    ep_rew_mean          | 98          |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 8           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003491842 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.517      |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.2        |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00785    |
# |    value_loss           | 98.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | 93           |
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 9            |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0038271532 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.426       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.6         |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.00684     |
# |    value_loss           | 106          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.28        |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 10          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.055428635 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.3        |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 39.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.04       |
# |    ep_rew_mean          | 95         |
# | time/                   |            |
# |    fps                  | 247        |
# |    iterations           | 11         |
# |    time_elapsed         | 91         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01146033 |
# |    clip_fraction        | 0.0928     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.618     |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.2       |
# |    n_updates            | 1080       |
# |    policy_gradient_loss | -0.00201   |
# |    value_loss           | 43.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.08        |
# |    ep_rew_mean          | 95          |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 12          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.036763467 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.656      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.9        |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 54.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7           |
# |    ep_rew_mean          | 95          |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 13          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007626206 |
# |    clip_fraction        | 0.0615      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.3        |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 48          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.14        |
# |    ep_rew_mean          | 98          |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 14          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.033684764 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.56        |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 50.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.04       |
# |    ep_rew_mean          | 98         |
# | time/                   |            |
# |    fps                  | 245        |
# |    iterations           | 15         |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.07412982 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.528     |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0394     |
# |    n_updates            | 1120       |
# |    policy_gradient_loss | -0.021     |
# |    value_loss           | 1.32       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.16       |
# |    ep_rew_mean          | 96         |
# | time/                   |            |
# |    fps                  | 246        |
# |    iterations           | 16         |
# |    time_elapsed         | 133        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.06278258 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.496     |
# |    explained_variance   | 0.988      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.117      |
# |    n_updates            | 1130       |
# |    policy_gradient_loss | -0.0118    |
# |    value_loss           | 21.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 17          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.022159196 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.267       |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 49.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.02        |
# |    ep_rew_mean          | 97          |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 18          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008089172 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.421      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.2        |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 18.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.02        |
# |    ep_rew_mean          | 99          |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 19          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025731191 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.477       |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | -0.00601    |
# |    value_loss           | 11.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.04        |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 20          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020168293 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.392      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.316       |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00776    |
# |    value_loss           | 47.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 97          |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 21          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013511406 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.536      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.956       |
# |    n_updates            | 1180        |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 24.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.04        |
# |    ep_rew_mean          | 95          |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 22          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016642954 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.461      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.702       |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 25.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.96       |
# |    ep_rew_mean          | 95         |
# | time/                   |            |
# |    fps                  | 244        |
# |    iterations           | 23         |
# |    time_elapsed         | 192        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02338292 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.52      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 75.2       |
# |    n_updates            | 1200       |
# |    policy_gradient_loss | -0.016     |
# |    value_loss           | 17.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.08       |
# |    ep_rew_mean          | 96         |
# | time/                   |            |
# |    fps                  | 245        |
# |    iterations           | 24         |
# |    time_elapsed         | 200        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.03341651 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.553     |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0132    |
# |    n_updates            | 1210       |
# |    policy_gradient_loss | -0.0196    |
# |    value_loss           | 5.69       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.96        |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 25          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.024527542 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.506      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0644      |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 6.09        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.1        |
# |    ep_rew_mean          | 97         |
# | time/                   |            |
# |    fps                  | 244        |
# |    iterations           | 26         |
# |    time_elapsed         | 217        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00438816 |
# |    clip_fraction        | 0.0634     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.44      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.64       |
# |    n_updates            | 1230       |
# |    policy_gradient_loss | -0.00181   |
# |    value_loss           | 35.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.1         |
# |    ep_rew_mean          | 99          |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 27          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.018035766 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00827     |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | -0.00939    |
# |    value_loss           | 34.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.02         |
# |    ep_rew_mean          | 95           |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 28           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0052393074 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01         |
# |    n_updates            | 1250         |
# |    policy_gradient_loss | -0.00742     |
# |    value_loss           | 27.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 29          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.020134687 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.455      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.9        |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 30.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.98        |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 30          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.019865064 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.447      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54          |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 18.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.94       |
# |    ep_rew_mean          | 94         |
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 31         |
# |    time_elapsed         | 260        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.02751098 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.461     |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.1       |
# |    n_updates            | 1280       |
# |    policy_gradient_loss | -0.0109    |
# |    value_loss           | 31.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.02       |
# |    ep_rew_mean          | 98         |
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 32         |
# |    time_elapsed         | 269        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00361074 |
# |    clip_fraction        | 0.0392     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.515     |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.12       |
# |    n_updates            | 1290       |
# |    policy_gradient_loss | -0.00637   |
# |    value_loss           | 27.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.94        |
# |    ep_rew_mean          | 94          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 33          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.027484152 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.222       |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 14.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 97          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 34          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.022544514 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00887    |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 5.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.02        |
# |    ep_rew_mean          | 97          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 35          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011698157 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.448       |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 5.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.96        |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 36          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005930454 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.501      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.2        |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.00747    |
# |    value_loss           | 34.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.16        |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 37          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.034139093 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000451    |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 98          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 38          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.015091197 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.1        |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 42.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 98          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 39          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.016315147 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60          |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 26.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.94        |
# |    ep_rew_mean          | 95          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 40          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007556297 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.502      |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 19.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.08        |
# |    ep_rew_mean          | 98          |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 41          |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.030803446 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0624      |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 9.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.02        |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 42          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.022819892 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0187      |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.96        |
# |    ep_rew_mean          | 95          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 43          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011336002 |
# |    clip_fraction        | 0.0911      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.84        |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 12.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.02         |
# |    ep_rew_mean          | 97           |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 44           |
# |    time_elapsed         | 369          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0028925189 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.452       |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 46.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.98        |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 45          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018743012 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.78        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 12.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 97          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 46          |
# |    time_elapsed         | 386         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009822894 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.471      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.267       |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 25.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 97           |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 47           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0035159036 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.524       |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.59         |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00312     |
# |    value_loss           | 28           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 98          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 48          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.020656079 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.398       |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.00541    |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.9         |
# |    ep_rew_mean          | 94          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 49          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.029767517 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.459      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0429      |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 8.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.06        |
# |    ep_rew_mean          | 95          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 50          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.028067034 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00168     |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 22.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.04        |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 51          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.004659141 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.521      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | -0.00332    |
# |    value_loss           | 58.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 92          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 52          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.049763355 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.58        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6            |
# |    ep_rew_mean          | 96           |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 53           |
# |    time_elapsed         | 445          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0051787407 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93         |
# |    n_updates            | 1500         |
# |    policy_gradient_loss | -0.00779     |
# |    value_loss           | 77.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.98         |
# |    ep_rew_mean          | 96           |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 54           |
# |    time_elapsed         | 453          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0043725288 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.623       |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 64.7         |
# |    n_updates            | 1510         |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 110          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.14        |
# |    ep_rew_mean          | 98          |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 55          |
# |    time_elapsed         | 462         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.019251315 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.502       |
# |    n_updates            | 1520        |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 29.5        |
# ...
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.3         |
# |    ep_rew_mean          | 81           |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 472          |
# |    time_elapsed         | 4826         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0019343661 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.313       |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67           |
# |    n_updates            | 5690         |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 183          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.4         |
# |    ep_rew_mean          | 89           |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 473          |
# |    time_elapsed         | 4833         |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0031760512 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.324       |
# |    explained_variance   | 0.785        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 82.7         |
# |    n_updates            | 5700         |
# |    policy_gradient_loss | -0.00968     |
# |    value_loss           | 181          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.6         |
# |    ep_rew_mean          | 94           |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 474          |
# |    time_elapsed         | 4841         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0053007985 |
# |    clip_fraction        | 0.0699       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.308       |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.3         |
# |    n_updates            | 5710         |
# |    policy_gradient_loss | -0.0124      |
# |    value_loss           | 133          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.3         |
# |    ep_rew_mean          | 91           |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 475          |
# |    time_elapsed         | 4849         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0049704956 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.281       |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.1         |
# |    n_updates            | 5720         |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 129          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.9         |
# |    ep_rew_mean          | 87           |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 476          |
# |    time_elapsed         | 4857         |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0071050897 |
# |    clip_fraction        | 0.0628       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.348       |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.1         |
# |    n_updates            | 5730         |
# |    policy_gradient_loss | -0.0099      |
# |    value_loss           | 97.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.9         |
# |    ep_rew_mean          | 93           |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 477          |
# |    time_elapsed         | 4864         |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0034441613 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.35        |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 5740         |
# |    policy_gradient_loss | -0.00456     |
# |    value_loss           | 99.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.6        |
# |    ep_rew_mean          | 91          |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 478         |
# |    time_elapsed         | 4873        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.007200336 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.36       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.7        |
# |    n_updates            | 5750        |
# |    policy_gradient_loss | -0.00852    |
# |    value_loss           | 121         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.52         |
# |    ep_rew_mean          | 95           |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 479          |
# |    time_elapsed         | 4880         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0050769243 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.363       |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.2         |
# |    n_updates            | 5760         |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 102          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.24       |
# |    ep_rew_mean          | 97         |
# | time/                   |            |
# |    fps                  | 201        |
# |    iterations           | 480        |
# |    time_elapsed         | 4889       |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.00596028 |
# |    clip_fraction        | 0.0635     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.408     |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.3       |
# |    n_updates            | 5770       |
# |    policy_gradient_loss | -0.00749   |
# |    value_loss           | 105        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.32        |
# |    ep_rew_mean          | 95          |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 481         |
# |    time_elapsed         | 4896        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.006028797 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.381      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.1        |
# |    n_updates            | 5780        |
# |    policy_gradient_loss | -0.00931    |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.4         |
# |    ep_rew_mean          | 98          |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 482         |
# |    time_elapsed         | 4904        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.009853889 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.426      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 5790        |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 134         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 483         |
# |    time_elapsed         | 4912        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.005265434 |
# |    clip_fraction        | 0.0533      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.4        |
# |    n_updates            | 5800        |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 232         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.1          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 201          |
# |    iterations           | 484          |
# |    time_elapsed         | 4920         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0058640204 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 130          |
# |    n_updates            | 5810         |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 273          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.5         |
# |    ep_rew_mean          | 98          |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 485         |
# |    time_elapsed         | 4927        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.013581904 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.203      |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 5820        |
# |    policy_gradient_loss | -0.00758    |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.6         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 486         |
# |    time_elapsed         | 4936        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.025136096 |
# |    clip_fraction        | 0.0709      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 5830        |
# |    policy_gradient_loss | -0.00914    |
# |    value_loss           | 59.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 487         |
# |    time_elapsed         | 4944        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.021490254 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0887     |
# |    explained_variance   | 0.0438      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.632       |
# |    n_updates            | 5840        |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 488         |
# |    time_elapsed         | 4952        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.013058546 |
# |    clip_fraction        | 0.0392      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.171      |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 5850        |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 42.1        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 20.3      |
# |    ep_rew_mean          | 85        |
# | time/                   |           |
# |    fps                  | 201       |
# |    iterations           | 489       |
# |    time_elapsed         | 4960      |
# |    total_timesteps      | 1001472   |
# | train/                  |           |
# |    approx_kl            | 1.1131804 |
# |    clip_fraction        | 0.32      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.275    |
# |    explained_variance   | -4.13     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0263    |
# |    n_updates            | 5860      |
# |    policy_gradient_loss | -0.0265   |
# |    value_loss           | 0.349     |
# ---------------------------------------

# %%
model.save('Rubiks_Cube_solver')

# %%
from stable_baselines3.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean reward: {mean_reward} +/- {std_reward:.2f}")
# Out:
# Mean reward: 0.0 +/- 0.00
